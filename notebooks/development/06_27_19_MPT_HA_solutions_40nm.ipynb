# %% [markdown]
# # Experiment Initialization

# %% [markdown]
# Here, the terms of the experiment are defined, such as the location of the files in S3 (bucket and folder name), and each of the video prefixes (everything before the file extension) that need to be tracked.
#
# Note that these videos should be similar-ish: while we can account for differences in mean intensities between videos, particle sizes should be approximately the same, and (slightly less important) particles should be moving at about the same order of magnitude speed. In this experiment, these videos were taken in 0.4% agarose gel at 100x magnification and 100.02 fps shutter speeds with nanoparticles of about 100nm in diameter.

# %%
to_track = [] # This is going to be the list of all filenames that will be included in the analysis
start_knot = 80 #Must be unique number for every run on Cloudknot.

remote_folder = '06_27_19_MPT_HA_solutions' # The folder in AWS S3 containing the files to be analyzed
bucket = 'mckenna.data' # The bucket in AWS S3 where the remote_folder is contained
NP_size = '40'
vids = 5 # this is the number of vids that were taken per condition (usually corresponding to different locations)
mol_weights = ['high', 'low', 'med']

for MW in mol_weights:
    for num in range(1, vids+1):
        to_track.append('{}MW_'.format(MW)+NP_size+'nm_vid_{}_{}MW_'.format(num, MW)+NP_size+'nm_vid_{}'.format(num))

# %%
to_track
# Out:
# ['highMW_40nm_vid_1_highMW_40nm_vid_1',
#  'highMW_40nm_vid_2_highMW_40nm_vid_2',
#  'highMW_40nm_vid_3_highMW_40nm_vid_3',
#  'highMW_40nm_vid_4_highMW_40nm_vid_4',
#  'highMW_40nm_vid_5_highMW_40nm_vid_5',
#  'lowMW_40nm_vid_1_lowMW_40nm_vid_1',
#  'lowMW_40nm_vid_2_lowMW_40nm_vid_2',
#  'lowMW_40nm_vid_3_lowMW_40nm_vid_3',
#  'lowMW_40nm_vid_4_lowMW_40nm_vid_4',
#  'lowMW_40nm_vid_5_lowMW_40nm_vid_5',
#  'medMW_40nm_vid_1_medMW_40nm_vid_1',
#  'medMW_40nm_vid_2_medMW_40nm_vid_2',
#  'medMW_40nm_vid_3_medMW_40nm_vid_3',
#  'medMW_40nm_vid_4_medMW_40nm_vid_4',
#  'medMW_40nm_vid_5_medMW_40nm_vid_5']

# %% [markdown]
# The videos used with this analysis are fairly large (2048 x 2048 pixels and 651 frames), and in cases like this, the tracking algorithm can quickly eat up RAM. In this case, we chose to crop the videos to 512 x 512 images such that we can run our jobs on smaller EC2 instances with 16GB of RAM.
#
# Note that larger jobs can be made with user-defined functions such that splitting isn't necessary-- or perhaps an intermediate amount of memory that contains splitting, tracking, and msd calculation functions all performed on a single EC2 instance.
#
# The compiled functions in the knotlets module require access to buckets on AWS. In this case, we will be using a publicly (read-only) bucket. If users want to run this notebook on their own, will have to transfer files from nancelab.publicfiles to their own bucket, as it requires writing to S3 buckets.

# %%
import diff_classifier.knotlets as kn

# %%
# This cell uses the function kn.split() to split all of the videos contained in 'to_track' into 16 smaller videos on which the actual tracking will be performed
for prefix in to_track:
    kn.split(prefix, remote_folder=remote_folder, bucket=bucket)
# Out:
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_1_highMW_40nm_vid_1_0_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_1_highMW_40nm_vid_1_0_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_1_highMW_40nm_vid_1_0_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_1_highMW_40nm_vid_1_0_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_1_highMW_40nm_vid_1_1_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_1_highMW_40nm_vid_1_1_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_1_highMW_40nm_vid_1_1_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_1_highMW_40nm_vid_1_1_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_1_highMW_40nm_vid_1_2_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_1_highMW_40nm_vid_1_2_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_1_highMW_40nm_vid_1_2_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_1_highMW_40nm_vid_1_2_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_1_highMW_40nm_vid_1_3_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_1_highMW_40nm_vid_1_3_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_1_highMW_40nm_vid_1_3_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_1_highMW_40nm_vid_1_3_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_1_highMW_40nm_vid_1_0_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_1_highMW_40nm_vid_1_0_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_1_highMW_40nm_vid_1_0_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_1_highMW_40nm_vid_1_0_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_1_highMW_40nm_vid_1_1_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_1_highMW_40nm_vid_1_1_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_1_highMW_40nm_vid_1_1_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_1_highMW_40nm_vid_1_1_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_1_highMW_40nm_vid_1_2_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_1_highMW_40nm_vid_1_2_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_1_highMW_40nm_vid_1_2_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_1_highMW_40nm_vid_1_2_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_1_highMW_40nm_vid_1_3_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_1_highMW_40nm_vid_1_3_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_1_highMW_40nm_vid_1_3_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_1_highMW_40nm_vid_1_3_3.tif
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_2_highMW_40nm_vid_2_0_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_2_highMW_40nm_vid_2_0_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_2_highMW_40nm_vid_2_0_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_2_highMW_40nm_vid_2_0_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_2_highMW_40nm_vid_2_1_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_2_highMW_40nm_vid_2_1_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_2_highMW_40nm_vid_2_1_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_2_highMW_40nm_vid_2_1_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_2_highMW_40nm_vid_2_2_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_2_highMW_40nm_vid_2_2_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_2_highMW_40nm_vid_2_2_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_2_highMW_40nm_vid_2_2_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_2_highMW_40nm_vid_2_3_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_2_highMW_40nm_vid_2_3_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_2_highMW_40nm_vid_2_3_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_2_highMW_40nm_vid_2_3_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_2_highMW_40nm_vid_2_0_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_2_highMW_40nm_vid_2_0_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_2_highMW_40nm_vid_2_0_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_2_highMW_40nm_vid_2_0_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_2_highMW_40nm_vid_2_1_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_2_highMW_40nm_vid_2_1_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_2_highMW_40nm_vid_2_1_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_2_highMW_40nm_vid_2_1_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_2_highMW_40nm_vid_2_2_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_2_highMW_40nm_vid_2_2_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_2_highMW_40nm_vid_2_2_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_2_highMW_40nm_vid_2_2_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_2_highMW_40nm_vid_2_3_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_2_highMW_40nm_vid_2_3_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_2_highMW_40nm_vid_2_3_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_2_highMW_40nm_vid_2_3_3.tif
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_3_highMW_40nm_vid_3_0_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_3_highMW_40nm_vid_3_0_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_3_highMW_40nm_vid_3_0_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_3_highMW_40nm_vid_3_0_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_3_highMW_40nm_vid_3_1_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_3_highMW_40nm_vid_3_1_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_3_highMW_40nm_vid_3_1_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_3_highMW_40nm_vid_3_1_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_3_highMW_40nm_vid_3_2_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_3_highMW_40nm_vid_3_2_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_3_highMW_40nm_vid_3_2_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_3_highMW_40nm_vid_3_2_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_3_highMW_40nm_vid_3_3_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_3_highMW_40nm_vid_3_3_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_3_highMW_40nm_vid_3_3_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_3_highMW_40nm_vid_3_3_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_3_highMW_40nm_vid_3_0_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_3_highMW_40nm_vid_3_0_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_3_highMW_40nm_vid_3_0_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_3_highMW_40nm_vid_3_0_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_3_highMW_40nm_vid_3_1_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_3_highMW_40nm_vid_3_1_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_3_highMW_40nm_vid_3_1_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_3_highMW_40nm_vid_3_1_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_3_highMW_40nm_vid_3_2_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_3_highMW_40nm_vid_3_2_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_3_highMW_40nm_vid_3_2_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_3_highMW_40nm_vid_3_2_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_3_highMW_40nm_vid_3_3_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_3_highMW_40nm_vid_3_3_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_3_highMW_40nm_vid_3_3_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_3_highMW_40nm_vid_3_3_3.tif
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_4_highMW_40nm_vid_4_0_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_4_highMW_40nm_vid_4_0_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_4_highMW_40nm_vid_4_0_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_4_highMW_40nm_vid_4_0_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_4_highMW_40nm_vid_4_1_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_4_highMW_40nm_vid_4_1_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_4_highMW_40nm_vid_4_1_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_4_highMW_40nm_vid_4_1_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_4_highMW_40nm_vid_4_2_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_4_highMW_40nm_vid_4_2_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_4_highMW_40nm_vid_4_2_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_4_highMW_40nm_vid_4_2_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_4_highMW_40nm_vid_4_3_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_4_highMW_40nm_vid_4_3_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_4_highMW_40nm_vid_4_3_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_4_highMW_40nm_vid_4_3_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_4_highMW_40nm_vid_4_0_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_4_highMW_40nm_vid_4_0_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_4_highMW_40nm_vid_4_0_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_4_highMW_40nm_vid_4_0_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_4_highMW_40nm_vid_4_1_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_4_highMW_40nm_vid_4_1_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_4_highMW_40nm_vid_4_1_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_4_highMW_40nm_vid_4_1_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_4_highMW_40nm_vid_4_2_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_4_highMW_40nm_vid_4_2_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_4_highMW_40nm_vid_4_2_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_4_highMW_40nm_vid_4_2_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_4_highMW_40nm_vid_4_3_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_4_highMW_40nm_vid_4_3_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_4_highMW_40nm_vid_4_3_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_4_highMW_40nm_vid_4_3_3.tif
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_5_highMW_40nm_vid_5_0_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_5_highMW_40nm_vid_5_0_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_5_highMW_40nm_vid_5_0_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_5_highMW_40nm_vid_5_0_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_5_highMW_40nm_vid_5_1_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_5_highMW_40nm_vid_5_1_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_5_highMW_40nm_vid_5_1_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_5_highMW_40nm_vid_5_1_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_5_highMW_40nm_vid_5_2_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_5_highMW_40nm_vid_5_2_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_5_highMW_40nm_vid_5_2_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_5_highMW_40nm_vid_5_2_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_5_highMW_40nm_vid_5_3_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_5_highMW_40nm_vid_5_3_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_5_highMW_40nm_vid_5_3_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/highMW_40nm_vid_5_highMW_40nm_vid_5_3_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_5_highMW_40nm_vid_5_0_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_5_highMW_40nm_vid_5_0_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_5_highMW_40nm_vid_5_0_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_5_highMW_40nm_vid_5_0_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_5_highMW_40nm_vid_5_1_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_5_highMW_40nm_vid_5_1_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_5_highMW_40nm_vid_5_1_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_5_highMW_40nm_vid_5_1_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_5_highMW_40nm_vid_5_2_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_5_highMW_40nm_vid_5_2_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_5_highMW_40nm_vid_5_2_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_5_highMW_40nm_vid_5_2_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_5_highMW_40nm_vid_5_3_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_5_highMW_40nm_vid_5_3_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_5_highMW_40nm_vid_5_3_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/highMW_40nm_vid_5_highMW_40nm_vid_5_3_3.tif
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_1_lowMW_40nm_vid_1_0_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_1_lowMW_40nm_vid_1_0_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_1_lowMW_40nm_vid_1_0_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_1_lowMW_40nm_vid_1_0_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_1_lowMW_40nm_vid_1_1_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_1_lowMW_40nm_vid_1_1_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_1_lowMW_40nm_vid_1_1_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_1_lowMW_40nm_vid_1_1_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_1_lowMW_40nm_vid_1_2_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_1_lowMW_40nm_vid_1_2_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_1_lowMW_40nm_vid_1_2_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_1_lowMW_40nm_vid_1_2_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_1_lowMW_40nm_vid_1_3_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_1_lowMW_40nm_vid_1_3_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_1_lowMW_40nm_vid_1_3_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_1_lowMW_40nm_vid_1_3_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_1_lowMW_40nm_vid_1_0_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_1_lowMW_40nm_vid_1_0_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_1_lowMW_40nm_vid_1_0_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_1_lowMW_40nm_vid_1_0_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_1_lowMW_40nm_vid_1_1_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_1_lowMW_40nm_vid_1_1_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_1_lowMW_40nm_vid_1_1_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_1_lowMW_40nm_vid_1_1_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_1_lowMW_40nm_vid_1_2_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_1_lowMW_40nm_vid_1_2_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_1_lowMW_40nm_vid_1_2_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_1_lowMW_40nm_vid_1_2_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_1_lowMW_40nm_vid_1_3_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_1_lowMW_40nm_vid_1_3_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_1_lowMW_40nm_vid_1_3_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_1_lowMW_40nm_vid_1_3_3.tif
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_2_lowMW_40nm_vid_2_0_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_2_lowMW_40nm_vid_2_0_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_2_lowMW_40nm_vid_2_0_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_2_lowMW_40nm_vid_2_0_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_2_lowMW_40nm_vid_2_1_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_2_lowMW_40nm_vid_2_1_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_2_lowMW_40nm_vid_2_1_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_2_lowMW_40nm_vid_2_1_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_2_lowMW_40nm_vid_2_2_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_2_lowMW_40nm_vid_2_2_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_2_lowMW_40nm_vid_2_2_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_2_lowMW_40nm_vid_2_2_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_2_lowMW_40nm_vid_2_3_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_2_lowMW_40nm_vid_2_3_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_2_lowMW_40nm_vid_2_3_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_2_lowMW_40nm_vid_2_3_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_2_lowMW_40nm_vid_2_0_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_2_lowMW_40nm_vid_2_0_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_2_lowMW_40nm_vid_2_0_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_2_lowMW_40nm_vid_2_0_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_2_lowMW_40nm_vid_2_1_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_2_lowMW_40nm_vid_2_1_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_2_lowMW_40nm_vid_2_1_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_2_lowMW_40nm_vid_2_1_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_2_lowMW_40nm_vid_2_2_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_2_lowMW_40nm_vid_2_2_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_2_lowMW_40nm_vid_2_2_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_2_lowMW_40nm_vid_2_2_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_2_lowMW_40nm_vid_2_3_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_2_lowMW_40nm_vid_2_3_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_2_lowMW_40nm_vid_2_3_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_2_lowMW_40nm_vid_2_3_3.tif
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_3_lowMW_40nm_vid_3_0_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_3_lowMW_40nm_vid_3_0_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_3_lowMW_40nm_vid_3_0_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_3_lowMW_40nm_vid_3_0_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_3_lowMW_40nm_vid_3_1_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_3_lowMW_40nm_vid_3_1_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_3_lowMW_40nm_vid_3_1_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_3_lowMW_40nm_vid_3_1_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_3_lowMW_40nm_vid_3_2_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_3_lowMW_40nm_vid_3_2_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_3_lowMW_40nm_vid_3_2_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_3_lowMW_40nm_vid_3_2_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_3_lowMW_40nm_vid_3_3_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_3_lowMW_40nm_vid_3_3_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_3_lowMW_40nm_vid_3_3_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/lowMW_40nm_vid_3_lowMW_40nm_vid_3_3_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_3_lowMW_40nm_vid_3_0_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_3_lowMW_40nm_vid_3_0_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_3_lowMW_40nm_vid_3_0_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/lowMW_40nm_vid_3_lowMW_40nm_vid_3_0_3.tif
# ...
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_3_medMW_40nm_vid_3_2_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_3_medMW_40nm_vid_3_2_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_3_medMW_40nm_vid_3_2_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_3_medMW_40nm_vid_3_3_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_3_medMW_40nm_vid_3_3_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_3_medMW_40nm_vid_3_3_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_3_medMW_40nm_vid_3_3_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_3_medMW_40nm_vid_3_0_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_3_medMW_40nm_vid_3_0_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_3_medMW_40nm_vid_3_0_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_3_medMW_40nm_vid_3_0_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_3_medMW_40nm_vid_3_1_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_3_medMW_40nm_vid_3_1_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_3_medMW_40nm_vid_3_1_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_3_medMW_40nm_vid_3_1_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_3_medMW_40nm_vid_3_2_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_3_medMW_40nm_vid_3_2_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_3_medMW_40nm_vid_3_2_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_3_medMW_40nm_vid_3_2_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_3_medMW_40nm_vid_3_3_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_3_medMW_40nm_vid_3_3_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_3_medMW_40nm_vid_3_3_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_3_medMW_40nm_vid_3_3_3.tif
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_4_medMW_40nm_vid_4_0_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_4_medMW_40nm_vid_4_0_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_4_medMW_40nm_vid_4_0_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_4_medMW_40nm_vid_4_0_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_4_medMW_40nm_vid_4_1_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_4_medMW_40nm_vid_4_1_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_4_medMW_40nm_vid_4_1_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_4_medMW_40nm_vid_4_1_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_4_medMW_40nm_vid_4_2_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_4_medMW_40nm_vid_4_2_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_4_medMW_40nm_vid_4_2_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_4_medMW_40nm_vid_4_2_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_4_medMW_40nm_vid_4_3_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_4_medMW_40nm_vid_4_3_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_4_medMW_40nm_vid_4_3_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_4_medMW_40nm_vid_4_3_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_4_medMW_40nm_vid_4_0_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_4_medMW_40nm_vid_4_0_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_4_medMW_40nm_vid_4_0_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_4_medMW_40nm_vid_4_0_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_4_medMW_40nm_vid_4_1_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_4_medMW_40nm_vid_4_1_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_4_medMW_40nm_vid_4_1_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_4_medMW_40nm_vid_4_1_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_4_medMW_40nm_vid_4_2_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_4_medMW_40nm_vid_4_2_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_4_medMW_40nm_vid_4_2_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_4_medMW_40nm_vid_4_2_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_4_medMW_40nm_vid_4_3_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_4_medMW_40nm_vid_4_3_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_4_medMW_40nm_vid_4_3_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_4_medMW_40nm_vid_4_3_3.tif
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_5_medMW_40nm_vid_5_0_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_5_medMW_40nm_vid_5_0_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_5_medMW_40nm_vid_5_0_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_5_medMW_40nm_vid_5_0_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_5_medMW_40nm_vid_5_1_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_5_medMW_40nm_vid_5_1_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_5_medMW_40nm_vid_5_1_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_5_medMW_40nm_vid_5_1_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_5_medMW_40nm_vid_5_2_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_5_medMW_40nm_vid_5_2_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_5_medMW_40nm_vid_5_2_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_5_medMW_40nm_vid_5_2_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_5_medMW_40nm_vid_5_3_0.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_5_medMW_40nm_vid_5_3_1.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_5_medMW_40nm_vid_5_3_2.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: /home/ubuntu/source/mike_fork/diff_classifier/notebooks/development/medMW_40nm_vid_5_medMW_40nm_vid_5_3_3.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_5_medMW_40nm_vid_5_0_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_5_medMW_40nm_vid_5_0_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_5_medMW_40nm_vid_5_0_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_5_medMW_40nm_vid_5_0_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_5_medMW_40nm_vid_5_1_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_5_medMW_40nm_vid_5_1_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_5_medMW_40nm_vid_5_1_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_5_medMW_40nm_vid_5_1_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_5_medMW_40nm_vid_5_2_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_5_medMW_40nm_vid_5_2_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_5_medMW_40nm_vid_5_2_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_5_medMW_40nm_vid_5_2_3.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_5_medMW_40nm_vid_5_3_0.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_5_medMW_40nm_vid_5_3_1.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_5_medMW_40nm_vid_5_3_2.tif
# Done with splitting. Should output file of name 06_27_19_MPT_HA_solutions/medMW_40nm_vid_5_medMW_40nm_vid_5_3_3.tif

# %% [markdown]
# ## Tracking predictor

# %% [markdown]
# Tracking normally requires user input in the form of tracking parameters e.g. particle radius, linking max distance, max frame gap etc. When large datasets aren't required, each video can be manageably manually tracked using the TrackMate GUI. However, when datasets get large e.g. >20 videos, this can become extremely arduous. For videos that are fairly similar, you can get away with using similar tracking parameters across all videos. However, one parameter that is a little more noisy that the others is the quality filter value. Quality is a numerical value that approximate how likely a particle is to be "real."
#
# In this case, I built a predictor that estimates the quality filter value based on intensity distributions from the input images. Using a relatively small training dataset (5-20 videos), users can get fairly good estimates of quality filter values that can be used in parallelized tracking workflows.
#
# Note: in the current setup, the predictor should be run in Python 3. While the code will run in Python 3, there are differences between the random number generators in Python2 and Python3 that I was not able to control for.

# %%
import os
import diff_classifier.imagej as ij
import boto3
import os.path as op
import diff_classifier.aws as aws
import diff_classifier.knotlets as kn
import numpy as np
from sklearn.externals import joblib

# %% [markdown]
# The regress_sys function should be run twice. When have_output is set to False, it generates a list of files that the user should manually track using Trackmate. Once the quality filter values are found, they can be used as input (y) to generate a regress object that can predict quality filter values for additional videos. Once y is assigned, set have_output to True and re-run the cell.

# %%
tnum=20 #number of training datasets
pref = []
for num in to_track:                    
    for row in range(0, 4):
        for col in range(0, 4):
            pref.append("{}_{}_{}".format(num, row, col))

y = np.array([3.07, 1.69, 2.60, 2.60, 0.86, 1.65, 1.05, 3.09, 1.03, 0.99, 1.29, 1.21, 3.86, 3.00, 2.93, 1.11, 1.06, 3.11, 1.54, 1.36])

# Creates regression object based of training dataset composed of input images and manually
# calculated quality cutoffs from tracking with GUI interface.
regress = ij.regress_sys(remote_folder, pref, y, tnum, randselect=True,
                         have_output=True, bucket_name=bucket)
#Read up on how regress_sys works before running.
# Out:
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:84: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:84: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.passive_aggressive.PassiveAggressiveRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
#Pickle object
filename = 'regress.obj'
with open(filename,'wb') as fp:
    joblib.dump(regress,fp)

import boto3
s3 = boto3.client('s3')
aws.upload_s3(filename, remote_folder+'/'+filename, bucket_name=bucket)

# %% [markdown]
# Users should input all tracking parameters into the tparams object. Note that the quality value will be overwritten by values found using the quality predictor found above. Never change threshold, median intensity, or snr

# %%
tparams1 = {'radius': 6.0, 'threshold': 0.0, 'do_median_filtering': False,
           'quality': 10.0, 'xdims': (0, 511), 'ydims': (1, 511),
           'median_intensity': 300.0, 'snr': 0.0, 'linking_max_distance': 15.0,
           'gap_closing_max_distance': 17.0, 'max_frame_gap': 8,
           'track_duration': 8.00}

# %% [markdown]
# ## Cloudknot setup

# %% [markdown]
# Cloudknot requires the user to define a function that will be sent to multiple computers to run. In this case, the function knotlets.tracking will be used. We create a docker image that has the required installations (defined by the requirements.txt file from diff_classifier on Github, and the base Docker Image below that has Fiji pre-installed in the correct location.
#
# Note that I modify the Docker image below such that the correct version of boto3 is installed. For some reason, versions later than 1.5.28 error out, so I specified 5.28 as the correct version. Run my_image.build below to double-check that the Docker image is successfully built prior to submitting the job to Cloudknot.

# %% [markdown]
# ** Before you run this next cell, you have to switch the kernel from Python 3 to Python 2, by doing the following: **
#  1. Kernel -> Restart and clear output
#  2. Kernel -> Change Kernel -> Python 2
#  3. Rerun cells required to run below cell
#
#  ** One other important thing to note:
#  - If you are performing the tracking, be sure that the my_image =  line is set to ck.DockerImage(func=kn.tracking,...
#  - If you are performing the MSD/feature calculation (after you've carried out the tracking), be sure that the my_image = line is se to ck.DockerImage(func=kn.assemble_msds, ...
#
#      ** following the tracking, before you run assemble_msds, you need to run the cell below that redefines all_maps as all_maps2. all_maps2 doesn't include the tparams1 input, and allows the kn.assemble_msds section to run properly. It won't work with the tparams input. **
#
#  Other than that, everything else should stay the same

# %%
import cloudknot as ck
import os.path as op

github_installs=('https://github.com/ccurtis7/diff_classifier.git')
#my_image = ck.DockerImage(func=kn.tracking, base_image='arokem/python3-fiji:0.3', github_installs=github_installs)
my_image = ck.DockerImage(func=kn.assemble_msds, base_image='arokem/python3-fiji:0.3', github_installs=github_installs)
docker_file = open(my_image.docker_path)
docker_string = docker_file.read()
docker_file.close()

req = open(op.join(op.split(my_image.docker_path)[0], 'requirements.txt'))
req_string = req.read()
req.close()

new_req = req_string[0:req_string.find('\n')-5]+'5.28'+ req_string[req_string.find('\n'):]
req_overwrite = open(op.join(op.split(my_image.docker_path)[0], 'requirements.txt'), 'w')
req_overwrite.write(new_req)
req_overwrite.close()

# %% [markdown]
# Following the execution of this cell, you have to check that the requirements.txt file has the first line 'boto3==1.5.28'.
#     - This file can be found in source -> diff-classifier -> notebooks -> development -> most recent file
#
# If it doesn't, you may have to change the line in the cell above that says 'new_req = reg_string[0:req_string.find('\n')-4]+'5.28'+ reg_string[reg_string.find('\n'):]'

# %%
my_image.build("ChABC_slice_2", image_name="test_image")

# %%
to_track
# Out:
# ['highMW_40nm_vid_1_highMW_40nm_vid_1',
#  'highMW_40nm_vid_2_highMW_40nm_vid_2',
#  'highMW_40nm_vid_3_highMW_40nm_vid_3',
#  'highMW_40nm_vid_4_highMW_40nm_vid_4',
#  'highMW_40nm_vid_5_highMW_40nm_vid_5',
#  'lowMW_40nm_vid_1_lowMW_40nm_vid_1',
#  'lowMW_40nm_vid_2_lowMW_40nm_vid_2',
#  'lowMW_40nm_vid_3_lowMW_40nm_vid_3',
#  'lowMW_40nm_vid_4_lowMW_40nm_vid_4',
#  'lowMW_40nm_vid_5_lowMW_40nm_vid_5',
#  'medMW_40nm_vid_1_medMW_40nm_vid_1',
#  'medMW_40nm_vid_2_medMW_40nm_vid_2',
#  'medMW_40nm_vid_3_medMW_40nm_vid_3',
#  'medMW_40nm_vid_4_medMW_40nm_vid_4',
#  'medMW_40nm_vid_5_medMW_40nm_vid_5']

# %% [markdown]
# The object all_maps is an iterable containing all the inputs sent to Cloudknot. This is useful, because if the user needs to modify some of the tracking parameters for a single video, this can be done prior to submission to Cloudknot.

# %%
names = []
all_maps = []
for prefix in to_track:    
    for i in range(0, 4):
        for j in range(0, 4):
            names.append('{}_{}_{}'.format(prefix, i, j))
            all_maps.append(('{}_{}_{}'.format(prefix, i, j), remote_folder, bucket, 'regress.obj', 4, 4, (512, 512), tparams1))

# %%
start_knot = 88

# %% [markdown]
# The Cloudknot knot object sets up the compute environment which will run the code. Note that the name must be unique. Every time you submit a new knot, you should change the name. I do this with the variable start_knot, which I vary for each run.
#
# If larger jobs are anticipated, users can adjust both RAM and storage with the memory and image_id variables. Memory specifies the amount of RAM to be used. Users can build a customized AMI with as much space as they need, and enter the ID into image_ID. Read the Cloudknot documentation for more details.

# %%
knot = ck.Knot(name='{}_b{}'.format('mike', start_knot),
               docker_image = my_image,
               memory = 16000,
               resource_type = "SPOT",
               bid_percentage = 100,
               #image_id = 'ami-0e00afdf500081a0d', #May need to change this line
               pars_policies=('AmazonS3FullAccess',))

result_futures = knot.map(all_maps2, starmap=True)

# %%
knot.clobber()

# %% [markdown]
# You can track the progression of your run using the AWS Batch service online -- make sure you are looking at the right US Region.
#
# After the run, you might have some that fail. This usually happens when the computers get claimed by someone paying more money, and your job gets booted from the aws computers. Because of this, you will need to start a knw cloudknot knot and rerun those vids. The set up for that is shown below.
#
# Remember to clobber your knot!

# %%
ck.get_region()

# %% [markdown]
# This creates a new all_maps2 array for any of the videos that failed to get analyzed the first time through. Double check that it worked well by printing the length of it immediately afterwards.

# %%
missing = []
all_maps2 = []
import boto3
import botocore

s3 = boto3.resource('s3')


for name in names:
    try:
        s3.Object(bucket, '{}/Traj_{}.csv'.format(remote_folder, name)).load()
    except botocore.exceptions.ClientError as e:
        if e.response['Error']['Code'] == "404":
            missing.append(name)
            all_maps2.append((name, remote_folder, bucket, 'regress.obj',
                             4, 4, (512, 512), tparams1))
        else:
            print('Something else has gone wrong')

# %%
print(len(all_maps2))
# Out:
# 2

# %% [markdown]
# Make sure you change the name of your knot, either by changing the 'mike1' part or start_knot value.

# %%
all_maps2 = []
for prefix in to_track:
    all_maps2.append((prefix, remote_folder, bucket, (512, 512), 651, 4, 4))

# %% [markdown]
# Users can monitor the progress of their job in the Batch interface. Once the code is complete, users should clobber their knot to make sure that all AWS resources are removed.

# %%
to_track

# %% [markdown]
# ## Downstream analysis and visualization

# %% [markdown]
# The knotlet.assemble_msds function (which can also potentially be submitted to Cloudknot as well for large jobs) calculates the mean squared displacements and trajectory features from the raw trajectory csv files found from the Cloudknot submission. It accesses them from the S3 bucket to which they were saved.

# %%
for prefix in to_track:
    kn.assemble_msds(prefix, remote_folder, bucket='mckenna.data')
    print('Successfully output msds for {}'.format(prefix))

# %%
for prefix in to_track[5:7]:
    kn.assemble_msds(prefix, remote_folder, bucket='ccurtis.data')
    print('Successfully output msds for {}'.format(prefix))

# %% [markdown]
# Diff_classifier includes some useful imaging tools as well, including checking trajectories, plotting heatmaps of trajectory features, distributions of diffusion coefficients, and MSD plots.

# %%
import diff_classifier.heatmaps as hm
import diff_classifier.aws as aws

# %%
to_track
# Out:
# ['highMW_40nm_vid_1_highMW_40nm_vid_1',
#  'highMW_40nm_vid_2_highMW_40nm_vid_2',
#  'highMW_40nm_vid_3_highMW_40nm_vid_3',
#  'highMW_40nm_vid_4_highMW_40nm_vid_4',
#  'highMW_40nm_vid_5_highMW_40nm_vid_5',
#  'lowMW_40nm_vid_1_lowMW_40nm_vid_1',
#  'lowMW_40nm_vid_2_lowMW_40nm_vid_2',
#  'lowMW_40nm_vid_3_lowMW_40nm_vid_3',
#  'lowMW_40nm_vid_4_lowMW_40nm_vid_4',
#  'lowMW_40nm_vid_5_lowMW_40nm_vid_5',
#  'medMW_40nm_vid_1_medMW_40nm_vid_1',
#  'medMW_40nm_vid_2_medMW_40nm_vid_2',
#  'medMW_40nm_vid_3_medMW_40nm_vid_3',
#  'medMW_40nm_vid_4_medMW_40nm_vid_4',
#  'medMW_40nm_vid_5_medMW_40nm_vid_5']

# %%
for vids in to_track:
    prefix = vids
    msds = 'msd_{}.csv'.format(prefix)
    feat = 'features_{}.csv'.format(prefix)
    aws.download_s3('{}/{}'.format(remote_folder, msds), msds, bucket_name=bucket)
    aws.download_s3('{}/{}'.format(remote_folder, feat), feat, bucket_name=bucket)
    hm.plot_trajectories(prefix, remote_folder=remote_folder, upload=True, figsize=(8, 8), bucket = bucket)
    print('Successfully uploaded trajectory plot for {}'.format(prefix))
    geomean, geoSEM = hm.plot_individual_msds(prefix, x_range=4, y_range=0.5, umppx=0.07, fps=33, upload=True, remote_folder=remote_folder, bucket = bucket)
    aws.upload_s3('./geomean_{}.csv'.format(prefix), remote_folder+'/geomean_{}.csv'.format(prefix), bucket_name = bucket)
    aws.upload_s3('./geoSEM_{}.csv'.format(prefix), remote_folder+'/geoSEM_{}.csv'.format(prefix), bucket_name = bucket)
    aws.upload_s3('./msds_{}.png'.format(prefix), remote_folder+'/msds_{}.png'.format(prefix), bucket_name = bucket)
    print('Successfully uploaded csv files for {}'.format(prefix))
# Out:
# Plotted highMW_40nm_vid_1_highMW_40nm_vid_1 trajectories successfully.
# Successfully uploaded trajectory plot for highMW_40nm_vid_1_highMW_40nm_vid_1
# Successfully uploaded csv files for highMW_40nm_vid_1_highMW_40nm_vid_1
# Plotted highMW_40nm_vid_2_highMW_40nm_vid_2 trajectories successfully.
# Successfully uploaded trajectory plot for highMW_40nm_vid_2_highMW_40nm_vid_2
# Successfully uploaded csv files for highMW_40nm_vid_2_highMW_40nm_vid_2
# Plotted highMW_40nm_vid_3_highMW_40nm_vid_3 trajectories successfully.
# Successfully uploaded trajectory plot for highMW_40nm_vid_3_highMW_40nm_vid_3
# Successfully uploaded csv files for highMW_40nm_vid_3_highMW_40nm_vid_3
# Plotted highMW_40nm_vid_4_highMW_40nm_vid_4 trajectories successfully.
# Successfully uploaded trajectory plot for highMW_40nm_vid_4_highMW_40nm_vid_4
# Successfully uploaded csv files for highMW_40nm_vid_4_highMW_40nm_vid_4
# Plotted highMW_40nm_vid_5_highMW_40nm_vid_5 trajectories successfully.
# Successfully uploaded trajectory plot for highMW_40nm_vid_5_highMW_40nm_vid_5
# Successfully uploaded csv files for highMW_40nm_vid_5_highMW_40nm_vid_5
# Plotted lowMW_40nm_vid_1_lowMW_40nm_vid_1 trajectories successfully.
# Successfully uploaded trajectory plot for lowMW_40nm_vid_1_lowMW_40nm_vid_1
# Successfully uploaded csv files for lowMW_40nm_vid_1_lowMW_40nm_vid_1
# Plotted lowMW_40nm_vid_2_lowMW_40nm_vid_2 trajectories successfully.
# Successfully uploaded trajectory plot for lowMW_40nm_vid_2_lowMW_40nm_vid_2
# Successfully uploaded csv files for lowMW_40nm_vid_2_lowMW_40nm_vid_2
# Plotted lowMW_40nm_vid_3_lowMW_40nm_vid_3 trajectories successfully.
# Successfully uploaded trajectory plot for lowMW_40nm_vid_3_lowMW_40nm_vid_3
# Successfully uploaded csv files for lowMW_40nm_vid_3_lowMW_40nm_vid_3
# Plotted lowMW_40nm_vid_4_lowMW_40nm_vid_4 trajectories successfully.
# Successfully uploaded trajectory plot for lowMW_40nm_vid_4_lowMW_40nm_vid_4
# Successfully uploaded csv files for lowMW_40nm_vid_4_lowMW_40nm_vid_4
# Plotted lowMW_40nm_vid_5_lowMW_40nm_vid_5 trajectories successfully.
# Successfully uploaded trajectory plot for lowMW_40nm_vid_5_lowMW_40nm_vid_5
# Successfully uploaded csv files for lowMW_40nm_vid_5_lowMW_40nm_vid_5
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Plotted medMW_40nm_vid_1_medMW_40nm_vid_1 trajectories successfully.
# Successfully uploaded trajectory plot for medMW_40nm_vid_1_medMW_40nm_vid_1
# Successfully uploaded csv files for medMW_40nm_vid_1_medMW_40nm_vid_1
# Plotted medMW_40nm_vid_2_medMW_40nm_vid_2 trajectories successfully.
# Successfully uploaded trajectory plot for medMW_40nm_vid_2_medMW_40nm_vid_2
# Successfully uploaded csv files for medMW_40nm_vid_2_medMW_40nm_vid_2
# Plotted medMW_40nm_vid_3_medMW_40nm_vid_3 trajectories successfully.
# Successfully uploaded trajectory plot for medMW_40nm_vid_3_medMW_40nm_vid_3
# Successfully uploaded csv files for medMW_40nm_vid_3_medMW_40nm_vid_3
# Plotted medMW_40nm_vid_4_medMW_40nm_vid_4 trajectories successfully.
# Successfully uploaded trajectory plot for medMW_40nm_vid_4_medMW_40nm_vid_4
# Successfully uploaded csv files for medMW_40nm_vid_4_medMW_40nm_vid_4
# Plotted medMW_40nm_vid_5_medMW_40nm_vid_5 trajectories successfully.
# Successfully uploaded trajectory plot for medMW_40nm_vid_5_medMW_40nm_vid_5
# Successfully uploaded csv files for medMW_40nm_vid_5_medMW_40nm_vid_5

# %%
geomean, geoSEM = hm.plot_individual_msds(prefix, x_range=4, y_range=0.5, umppx=0.07, fps=100, upload=True, remote_folder=remote_folder, bucket = bucket)
aws.upload_s3('./geomean_{}.csv'.format(prefix), remote_folder+'/geomean_{}.csv'.format(prefix), bucket_name = bucket)
aws.upload_s3('./geoSEM_{}.csv'.format(prefix), remote_folder+'/geoSEM_{}.csv'.format(prefix), bucket_name = bucket)
aws.upload_s3('./msds_{}.png'.format(prefix), remote_folder+'/msds_{}.png'.format(prefix), bucket_name = bucket)

# %%
hm.plot_heatmap(prefix, upload=False)

# %%
hm.plot_particles_in_frame(prefix, y_range=500, upload=False)

# %%
prefix = to_track[0]

msds = 'msd_{}.csv'.format(prefix)
feat = 'features_{}.csv'.format(prefix)
aws.download_s3('{}/{}'.format(remote_folder, msds), msds, bucket_name=bucket)
aws.download_s3('{}/{}'.format(remote_folder, feat), feat, bucket_name=bucket)

# %%
hm.plot_trajectories(prefix, remote_folder=remote_folder, upload=True, figsize=(8, 8), bucket = bucket)

# %%
geomean, geoSEM = hm.plot_individual_msds(prefix, x_range=4, y_range=0.5, umppx=0.07, fps=100, upload=True, remote_folder=remote_folder, bucket = bucket)
aws.upload_s3('./geomean_{}.csv'.format(prefix), remote_folder+'/geomean_{}.csv'.format(prefix), bucket_name = bucket)
aws.upload_s3('./geoSEM_{}.csv'.format(prefix), remote_folder+'/geoSEM_{}.csv'.format(prefix), bucket_name = bucket)
aws.upload_s3('./msds_{}.png'.format(prefix), remote_folder+'/msds_{}.png'.format(prefix), bucket_name = bucket)

# %% [markdown]
# ## Converting msd files

# %%
import pandas as pd
import diff_classifier.aws as aws
import math

# %%
to_track = [] # This is going to be the list of all filenames that will be included in the analysis
start_knot = 80 #Must be unique number for every run on Cloudknot.

remote_folder = '06_27_19_MPT_HA_solutions' # The folder in AWS S3 containing the files to be analyzed
bucket = 'mckenna.data' # The bucket in AWS S3 where the remote_folder is contained
NP_size = '40'
vids = 5 # this is the number of vids that were taken per condition (usually corresponding to different locations)
mol_weights = ['high', 'low', 'med']

for MW in mol_weights:
    for num in range(1, vids+1):
        to_track.append('{}MW_'.format(MW)+NP_size+'nm_vid_{}_{}MW_'.format(num, MW)+NP_size+'nm_vid_{}'.format(num))

# %%
to_track
# Out:
# ['highMW_40nm_vid_1_highMW_40nm_vid_1',
#  'highMW_40nm_vid_2_highMW_40nm_vid_2',
#  'highMW_40nm_vid_3_highMW_40nm_vid_3',
#  'highMW_40nm_vid_4_highMW_40nm_vid_4',
#  'highMW_40nm_vid_5_highMW_40nm_vid_5',
#  'lowMW_40nm_vid_1_lowMW_40nm_vid_1',
#  'lowMW_40nm_vid_2_lowMW_40nm_vid_2',
#  'lowMW_40nm_vid_3_lowMW_40nm_vid_3',
#  'lowMW_40nm_vid_4_lowMW_40nm_vid_4',
#  'lowMW_40nm_vid_5_lowMW_40nm_vid_5',
#  'medMW_40nm_vid_1_medMW_40nm_vid_1',
#  'medMW_40nm_vid_2_medMW_40nm_vid_2',
#  'medMW_40nm_vid_3_medMW_40nm_vid_3',
#  'medMW_40nm_vid_4_medMW_40nm_vid_4',
#  'medMW_40nm_vid_5_medMW_40nm_vid_5']

# %%
import pandas as pd
import diff_classifier.aws as aws
import math

for prefix in to_track:
    filename = 'geomean_{}.csv'.format(prefix)
    aws.download_s3(remote_folder+'/'+filename, filename, bucket_name=bucket)
    local_name = filename
    merged = pd.read_csv(local_name)
    merged.columns = ['log']
    merged['exp'] = 0
    for rows in range(0,len(merged)):
        log_value = merged['log'].iloc[rows]
        exp_value = math.exp(log_value)
        merged.loc[rows,'exp'] = exp_value
    merged.to_csv('adj_'+filename, mode='w', index = False)
    aws.upload_s3('./adj_'+filename, remote_folder+'/adj_'+filename, bucket_name = bucket)

# %%
pref = 'adj_geomean_'

mol_wts = ['high', 'low', 'med']
num_vids = 5

for MW in mol_wts:
    avg_df = pd.DataFrame()
    for vid in range(1, num_vids+1):
        exp = pd.read_csv(pref+'{}MW_40nm_vid_{}_{}MW_40nm_vid_{}.csv'.format(MW, str(vid), MW, str(vid)))
        avg_df = pd.concat([avg_df, exp['exp']], axis=1)
    avg_df = avg_df.mean(axis = 1)
    avg_df.to_csv('avg_'+pref+'{}MW_40nm.csv'.format(MW), mode='w', index = False)
    aws.upload_s3('./avg_'+pref+'{}MW_40nm.csv'.format(MW), remote_folder+'/avg_'+pref+'{}MW_40nm.csv'.format(MW), bucket_name=bucket)

# %%
to_track
# Out:
# ['highMW_40nm_vid_1_highMW_40nm_vid_1',
#  'highMW_40nm_vid_2_highMW_40nm_vid_2',
#  'highMW_40nm_vid_3_highMW_40nm_vid_3',
#  'highMW_40nm_vid_4_highMW_40nm_vid_4',
#  'highMW_40nm_vid_5_highMW_40nm_vid_5',
#  'lowMW_40nm_vid_1_lowMW_40nm_vid_1',
#  'lowMW_40nm_vid_2_lowMW_40nm_vid_2',
#  'lowMW_40nm_vid_3_lowMW_40nm_vid_3',
#  'lowMW_40nm_vid_4_lowMW_40nm_vid_4',
#  'lowMW_40nm_vid_5_lowMW_40nm_vid_5',
#  'medMW_40nm_vid_1_medMW_40nm_vid_1',
#  'medMW_40nm_vid_2_medMW_40nm_vid_2',
#  'medMW_40nm_vid_3_medMW_40nm_vid_3',
#  'medMW_40nm_vid_4_medMW_40nm_vid_4',
#  'medMW_40nm_vid_5_medMW_40nm_vid_5']

# %%
high_track = to_track[0:4]
print(high_track)
# Out:
# ['highMW_40nm_vid_1_highMW_40nm_vid_1', 'highMW_40nm_vid_2_highMW_40nm_vid_2', 'highMW_40nm_vid_3_highMW_40nm_vid_3', 'highMW_40nm_vid_4_highMW_40nm_vid_4']

# %%
import pandas as pd
import diff_classifier.aws as aws
import math

high_track = to_track[0:4]
low_track = to_track[5:9]
med_track = to_track[10:14]

low_MW = pd.DataFrame()
med_MW = pd.DataFrame()
high_MW = pd.DataFrame()

for prefix in low_track:
    feat = 'features_{}.csv'.format(prefix)
    aws.download_s3(remote_folder+'/'+feat, feat, bucket_name=bucket)
    merged = pd.read_csv(feat)
    low_MW = pd.concat([low_MW, merged['Deff1']], axis=0)
    
for prefix in med_track:
    feat = 'features_{}.csv'.format(prefix)
    aws.download_s3(remote_folder+'/'+feat, feat, bucket_name=bucket)
    merged = pd.read_csv(feat)
    med_MW = pd.concat([med_MW, merged['Deff1']], axis=0)
    
for prefix in high_track:
    feat = 'features_{}.csv'.format(prefix)
    aws.download_s3(remote_folder+'/'+feat, feat, bucket_name=bucket)
    merged = pd.read_csv(feat)
    high_MW = pd.concat([high_MW, merged['Deff1']], axis=0)

# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.ma as ma

low_no_nan = low_MW.replace(0,np.nan)
med_no_nan = med_MW.replace(0,np.nan)
high_no_nan = high_MW.replace(0,np.nan)


log_Deff_low = np.log(low_no_nan[0].dropna())
log_Deff_med = np.log(med_no_nan[0].dropna())
log_Deff_high = np.log(high_no_nan[0].dropna())

test_bins = np.linspace(-8, 4, 76)

low_hist, test_bins = np.histogram(log_Deff_low, bins=test_bins)
med_hist, med_bins = np.histogram(log_Deff_med, bins=test_bins)
high_hist, high_bins = np.histogram(log_Deff_high, bins=test_bins)

low_avg = np.mean(log_Deff_low)
med_avg = np.mean(log_Deff_med)
high_avg = np.mean(log_Deff_high)

plt.rc('axes', linewidth=2)
low_plot, med_plot, high_plot = low_hist, med_hist, high_hist
bins = test_bins
width = 0.7 * (bins[1] - bins[0])
center = (bins[:-1] + bins[1:])/2

plt.figure(1, figsize=(7,4)).tight_layout()
plt.bar(center, low_plot, color='firebrick', align='center', width=width)
plt.axvline(low_avg, color='black', linestyle='--', linewidth=3)
plt.ylim((0,100))
plt.xlabel('log $D_{eff}$', fontsize=20)
plt.ylabel('Trajectory Count', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=12)

plt.figure(2, figsize=(7,4)).tight_layout()
plt.bar(center, med_plot, color='darkgreen', align='center', width=width)
plt.axvline(med_avg, color='black', linestyle='--', linewidth=3)
plt.ylim((0,400))
plt.xlabel('log $D_{eff}$', fontsize=20)
plt.ylabel('Trajectory Count', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=12)


plt.figure(3, figsize=(7,4)).tight_layout()
plt.bar(center, high_plot, color='royalblue', align='center', width=width)
plt.axvline(high_avg, color='black', linestyle='--', linewidth=3)
plt.ylim((0,800))
plt.xlabel('log $D_{eff}$', fontsize=20)
plt.ylabel('Trajectory Count', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.show()

# %%
print(low_avg, med_avg, high_avg)
# Out:
# 1.99866718165 -0.11227062448 -2.31571038397
